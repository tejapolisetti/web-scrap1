# %%
from selenium import webdriver
driver=webdriver.Chrome('/Users/ravi.teja1/Desktop/jupyter_files/week2/chromedriver')
f=open('data.txt','w')
driver.get("https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating,desc&count=100&ref_=adv_prv")
ans=[]
for i in range(10):
    temps=driver.find_elements_by_class_name('lister-item-content')
    for temp in temps:
        title=temp.find_element_by_class_name("lister-item-header")
        title=temp.find_element_by_tag_name("a")
        title=title.text
        print(title)

        rate=temp.find_element_by_class_name("ratings-imdb-rating")
        rate=rate.text
        print(rate)

        casts=[]
        cast=temp.find_elements_by_tag_name("p")
        cast=cast[2]
        cast=cast.find_elements_by_tag_name("a")
        for j in cast:
            casts.append(j.text)
        print(casts)
    
        print()
    
    if(i==0):
        break

    btn=driver.find_element_by_class_name('next-page')
    btn.click()
# Out:
# The Shawshank Redemption
# 9.3
# ['Frank Darabont', 'Tim Robbins', 'Morgan Freeman', 'Bob Gunton', 'William Sadler']
#
# The Godfather
# 9.2
# ['Francis Ford Coppola', 'Marlon Brando', 'Al Pacino', 'James Caan', 'Diane Keaton']
#
# The Dark Knight
# 9.0
# ['Christopher Nolan', 'Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine']
#
# The Godfather: Part II
# 9.0
# ['Francis Ford Coppola', 'Al Pacino', 'Robert De Niro', 'Robert Duvall', 'Diane Keaton']
#
# The Lord of the Rings: The Return of the King
# 8.9
# ['Peter Jackson', 'Elijah Wood', 'Viggo Mortensen', 'Ian McKellen', 'Orlando Bloom']
#
# Pulp Fiction
# 8.9
# ['Quentin Tarantino', 'John Travolta', 'Uma Thurman', 'Samuel L. Jackson', 'Bruce Willis']
#
# Schindler's List
# 8.9
# ['Steven Spielberg', 'Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley', 'Caroline Goodall']
#
# 12 Angry Men
# 8.9
# ['Sidney Lumet', 'Henry Fonda', 'Lee J. Cobb', 'Martin Balsam', 'John Fiedler']
#
# Inception
# 8.8
# ['Christopher Nolan', 'Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Ellen Page', 'Ken Watanabe']
#
# Fight Club
# 8.8
# ['David Fincher', 'Brad Pitt', 'Edward Norton', 'Meat Loaf', 'Zach Grenier']
#
# The Lord of the Rings: The Fellowship of the Ring
# 8.8
# ['Peter Jackson', 'Elijah Wood', 'Ian McKellen', 'Orlando Bloom', 'Sean Bean']
#
# Forrest Gump
# 8.8
# ['Robert Zemeckis', 'Tom Hanks', 'Robin Wright', 'Gary Sinise', 'Sally Field']
#
# The Good, the Bad and the Ugly
# 8.8
# ['Sergio Leone', 'Clint Eastwood', 'Eli Wallach', 'Lee Van Cleef', 'Aldo Giuffrè']
#
# Ayla: The Daughter of War
# 8.7
# ['Can Ulkay', 'Çetin Tekindor', 'Ismail Hacioglu', 'Kyung-jin Lee', 'Kim Seol']
#
# Avengers: Endgame
# 8.7
# ['Anthony Russo', 'Joe Russo', 'Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo', 'Chris Hemsworth']
#
# The Lord of the Rings: The Two Towers
# 8.7
# ['Peter Jackson', 'Elijah Wood', 'Ian McKellen', 'Viggo Mortensen', 'Orlando Bloom']
#
# The Matrix
# 8.7
# ['Lana Wachowski', 'Lilly Wachowski', 'Keanu Reeves', 'Laurence Fishburne', 'Carrie-Anne Moss', 'Hugo Weaving']
#
# Goodfellas
# 8.7
# ['Martin Scorsese', 'Robert De Niro', 'Ray Liotta', 'Joe Pesci', 'Lorraine Bracco']
#
# Star Wars: Episode V - The Empire Strikes Back
# 8.7
# ['Irvin Kershner', 'Mark Hamill', 'Harrison Ford', 'Carrie Fisher', 'Billy Dee Williams']
#
# One Flew Over the Cuckoo's Nest
# 8.7
# ['Milos Forman', 'Jack Nicholson', 'Louise Fletcher', 'Will Sampson', 'Michael Berryman']
#
# Seven Samurai
# 8.7
# ['Akira Kurosawa', 'Toshirô Mifune', 'Takashi Shimura', 'Keiko Tsushima', 'Yukiko Shimazaki']
#
# Uri: The Surgical Strike
# 8.6
# ['Aditya Dhar', 'Vicky Kaushal', 'Paresh Rawal', 'Yami Gautam', 'Mohit Raina']
#
# Interstellar
# 8.6
# ['Christopher Nolan', 'Matthew McConaughey', 'Anne Hathaway', 'Jessica Chastain', 'Mackenzie Foy']
#
# City of God
# 8.6
# ['Fernando Meirelles', 'Kátia Lund', 'Alexandre Rodrigues', 'Leandro Firmino', 'Matheus Nachtergaele', 'Phellipe Haagensen']
#
# Spirited Away
# 8.6
# ['Hayao Miyazaki', 'Kirk Wise', 'Daveigh Chase', 'Suzanne Pleshette', 'Miyu Irino', 'Rumi Hiiragi']
#
# Saving Private Ryan
# 8.6
# ['Steven Spielberg', 'Tom Hanks', 'Matt Damon', 'Tom Sizemore', 'Edward Burns']
#
# The Green Mile
# 8.6
# ['Frank Darabont', 'Tom Hanks', 'Michael Clarke Duncan', 'David Morse', 'Bonnie Hunt']
#
# Life Is Beautiful
# 8.6
# ['Roberto Benigni', 'Roberto Benigni', 'Nicoletta Braschi', 'Giorgio Cantarini', 'Giustino Durano']
#
# The Usual Suspects
# 8.6
# ['Bryan Singer', 'Kevin Spacey', 'Gabriel Byrne', 'Chazz Palminteri', 'Stephen Baldwin']
#
# Se7en
# 8.6
# ['David Fincher', 'Morgan Freeman', 'Brad Pitt', 'Kevin Spacey', 'Andrew Kevin Walker']
#
# Léon: The Professional
# 8.6
# ['Luc Besson', 'Jean Reno', 'Gary Oldman', 'Natalie Portman', 'Danny Aiello']
#
# The Silence of the Lambs
# 8.6
# ['Jonathan Demme', 'Jodie Foster', 'Anthony Hopkins', 'Lawrence A. Bonney', 'Kasi Lemmons']
#
# Star Wars: Episode IV - A New Hope
# 8.6
# ['George Lucas', 'Mark Hamill', 'Harrison Ford', 'Carrie Fisher', 'Alec Guinness']
#
# It's a Wonderful Life
# 8.6
# ['Frank Capra', 'James Stewart', 'Donna Reed', 'Lionel Barrymore', 'Thomas Mitchell']
#
# Dangal
# 8.5
# ['Nitesh Tiwari', 'Aamir Khan', 'Sakshi Tanwar', 'Fatima Sana Shaikh', 'Sanya Malhotra']
#
# Spider-Man: Into the Spider-Verse
# 8.5
# ['Bob Persichetti', 'Peter Ramsey', 'Rodney Rothman', 'Shameik Moore', 'Jake Johnson', 'Hailee Steinfeld', 'Mahershala Ali']
#
# Avengers: Infinity War
# 8.5
# ['Anthony Russo', 'Joe Russo', 'Robert Downey Jr.', 'Chris Hemsworth', 'Mark Ruffalo', 'Chris Evans']
#
# Whiplash
# 8.5
# ['Damien Chazelle', 'Miles Teller', 'J.K. Simmons', 'Melissa Benoist', 'Paul Reiser']
#
# The Intouchables
# 8.5
# ['Olivier Nakache', 'Éric Toledano', 'François Cluzet', 'Omar Sy', 'Anne Le Ny', 'Audrey Fleurot']
#
# The Prestige
# 8.5
# ['Christopher Nolan', 'Christian Bale', 'Hugh Jackman', 'Scarlett Johansson', 'Michael Caine']
#
# The Departed
# 8.5
# ['Martin Scorsese', 'Leonardo DiCaprio', 'Matt Damon', 'Jack Nicholson', 'Mark Wahlberg']
#
# The Pianist
# 8.5
# ['Roman Polanski', 'Adrien Brody', 'Thomas Kretschmann', 'Frank Finlay', 'Emilia Fox']
#
# Memento
# 8.5
# ['Christopher Nolan', 'Guy Pearce', 'Carrie-Anne Moss', 'Joe Pantoliano', 'Mark Boone Junior']
#
# Gladiator
# 8.5
# ['Ridley Scott', 'Russell Crowe', 'Joaquin Phoenix', 'Connie Nielsen', 'Oliver Reed']
#
# American History X
# 8.5
# ['Tony Kaye', 'Edward Norton', 'Edward Furlong', "Beverly D'Angelo", 'Jennifer Lien']
#
# The Lion King
# 8.5
# ['Roger Allers', 'Rob Minkoff', 'Matthew Broderick', 'Jeremy Irons', 'James Earl Jones', 'Whoopi Goldberg']
#
# Terminator 2: Judgment Day
# 8.5
# ['James Cameron', 'Arnold Schwarzenegger', 'Linda Hamilton', 'Edward Furlong', 'Robert Patrick']
#
# Cinema Paradiso
# 8.5
# ['Giuseppe Tornatore', 'Philippe Noiret', 'Enzo Cannavale', 'Antonella Attili', 'Isa Danieli']
#
# Grave of the Fireflies
# 8.5
# ['Isao Takahata', 'Tsutomu Tatsumi', 'Ayano Shiraishi', 'Akemi Yamaguchi', 'Yoshiko Shinohara']
#
# Back to the Future
# 8.5
# ['Robert Zemeckis', 'Michael J. Fox', 'Christopher Lloyd', 'Lea Thompson', 'Crispin Glover']
#
# Raiders of the Lost Ark
# 8.5
# ['Steven Spielberg', 'Harrison Ford', 'Karen Allen', 'Paul Freeman', 'John Rhys-Davies']
#
# Apocalypse Now
# 8.5
# ['Francis Ford Coppola', 'Martin Sheen', 'Marlon Brando', 'Robert Duvall', 'Frederic Forrest']
#
# Alien
# 8.5
# ['Ridley Scott', 'Sigourney Weaver', 'Tom Skerritt', 'John Hurt', 'Veronica Cartwright']
#
# Once Upon a Time in the West
# 8.5
# ['Sergio Leone', 'Henry Fonda', 'Charles Bronson', 'Claudia Cardinale', 'Jason Robards']
#
# Psycho
# 8.5
# ['Alfred Hitchcock', 'Anthony Perkins', 'Janet Leigh', 'Vera Miles', 'John Gavin']
#
# Rear Window
# 8.5
# ['Alfred Hitchcock', 'James Stewart', 'Grace Kelly', 'Wendell Corey', 'Thelma Ritter']
#
# Casablanca
# 8.5
# ['Michael Curtiz', 'Humphrey Bogart', 'Ingrid Bergman', 'Paul Henreid', 'Claude Rains']
#
# The Great Dictator
# 8.5
# ['Charles Chaplin', 'Charles Chaplin', 'Paulette Goddard', 'Jack Oakie', 'Reginald Gardiner']
#
# Modern Times
# 8.5
# ['Charles Chaplin', 'Charles Chaplin', 'Paulette Goddard', 'Henry Bergman', 'Tiny Sandford']
#
# City Lights
# 8.5
# ['Charles Chaplin', 'Charles Chaplin', 'Virginia Cherrill', 'Florence Lee', 'Harry Myers']
#
# Andhadhun
# 8.4
# ['Sriram Raghavan', 'Ayushmann Khurrana', 'Tabu', 'Radhika Apte', 'Anil Dhawan']
#
# Your Name.
# 8.4
# ['Makoto Shinkai', 'Ryûnosuke Kamiki', 'Mone Kamishiraishi', 'Ryô Narita', 'Aoi Yûki']
#
# Coco
# 8.4
# ['Lee Unkrich', 'Adrian Molina', 'Anthony Gonzalez', 'Gael García Bernal', 'Benjamin Bratt', 'Alanna Ubach']
#
# Toy Story 4
# 8.4
# ['Josh Cooley', 'Tom Hanks', 'Tim Allen', 'Annie Potts', 'Tony Hale']
#
# Django Unchained
# 8.4
# ['Quentin Tarantino', 'Jamie Foxx', 'Christoph Waltz', 'Leonardo DiCaprio', 'Kerry Washington']
#
# The Dark Knight Rises
# 8.4
# ['Christopher Nolan', 'Christian Bale', 'Tom Hardy', 'Anne Hathaway', 'Gary Oldman']
#
# 3 Idiots
# 8.4
# ['Rajkumar Hirani', 'Aamir Khan', 'Madhavan', 'Mona Singh', 'Sharman Joshi']
#
# Taare Zameen Par
# 8.4
# ['Aamir Khan', 'Amole Gupte', 'Darsheel Safary', 'Aamir Khan', 'Tisca Chopra', 'Vipin Sharma']
#
# WALL·E
# 8.4
# ['Andrew Stanton', 'Ben Burtt', 'Elissa Knight', 'Jeff Garlin', 'Fred Willard']
#
# My Father and My Son
# 8.4
# ['Çagan Irmak', 'Çetin Tekindor', 'Fikret Kuskan', 'Hümeyra', 'Ege Tanman']
#
# The Lives of Others
# 8.4
# ['Florian Henckel von Donnersmarck', 'Ulrich Mühe', 'Martina Gedeck', 'Sebastian Koch', 'Ulrich Tukur']
#
# Oldboy
# 8.4
# ['Chan-wook Park', 'Min-sik Choi', 'Ji-tae Yu', 'Hye-jeong Kang', 'Dae-han Ji']
#
# American Beauty
# 8.4
# ['Sam Mendes', 'Kevin Spacey', 'Annette Bening', 'Thora Birch', 'Wes Bentley']
#
# Princess Mononoke
# 8.4
# ['Hayao Miyazaki', 'Yôji Matsuda', 'Yuriko Ishida', 'Yûko Tanaka', 'Billy Crudup']
# Braveheart
# 8.4
# ['Mel Gibson', 'Mel Gibson', 'Sophie Marceau', 'Patrick McGoohan', 'Angus Macfadyen']
#
# Aliens
# 8.4
# ['James Cameron', 'Sigourney Weaver', 'Michael Biehn', 'Carrie Henn', 'Paul Reiser']
#
# Once Upon a Time in America
# 8.4
# ['Sergio Leone', 'Robert De Niro', 'James Woods', 'Elizabeth McGovern', 'Treat Williams']
#
# Das Boot
# 8.4
# ['Wolfgang Petersen', 'Jürgen Prochnow', 'Herbert Grönemeyer', 'Klaus Wennemann', 'Hubertus Bengsch']
#
# The Shining
# 8.4
# ['Stanley Kubrick', 'Jack Nicholson', 'Shelley Duvall', 'Danny Lloyd', 'Scatman Crothers']
#
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# 8.4
# ['Stanley Kubrick', 'Peter Sellers', 'George C. Scott', 'Sterling Hayden', 'Keenan Wynn']
#
# Witness for the Prosecution
# 8.4
# ['Billy Wilder', 'Tyrone Power', 'Marlene Dietrich', 'Charles Laughton', 'Elsa Lanchester']
#
# Paths of Glory
# 8.4
# ['Stanley Kubrick', 'Kirk Douglas', 'Ralph Meeker', 'Adolphe Menjou', 'George Macready']
#
# Sunset Blvd.
# 8.4
# ['Billy Wilder', 'William Holden', 'Gloria Swanson', 'Erich von Stroheim', 'Nancy Olson']
#
# Baahubali 2: The Conclusion
# 8.3
# ['S.S. Rajamouli', 'Prabhas', 'Rana Daggubati', 'Anushka Shetty', 'Tamannaah Bhatia']
#
# Drishyam
# 8.3
# ['Nishikant Kamat', 'Ajay Devgn', 'Shriya Saran', 'Tabu', 'Rajat Kapoor']
#
# The Hunt
# 8.3
# ['Thomas Vinterberg', 'Mads Mikkelsen', 'Thomas Bo Larsen', 'Annika Wedderkopp', 'Lasse Fogelstrøm']
#
# A Separation
# 8.3
# ['Asghar Farhadi', 'Payman Maadi', 'Leila Hatami', 'Sareh Bayat', 'Shahab Hosseini']
#
# Incendies
# 8.3
# ['Denis Villeneuve', 'Lubna Azabal', 'Mélissa Désormeaux-Poulin', 'Maxim Gaudette', 'Mustafa Kamel']
#
# Toy Story 3
# 8.3
# ['Lee Unkrich', 'Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Ned Beatty']
#
# Swades
# 8.3
# ['Ashutosh Gowariker', 'Shah Rukh Khan', 'Gayatri Joshi', 'Kishori Ballal', 'Smit Sheth']
#
# Inglourious Basterds
# 8.3
# ['Quentin Tarantino', 'Brad Pitt', 'Diane Kruger', 'Eli Roth', 'Mélanie Laurent']
#
# Eternal Sunshine of the Spotless Mind
# 8.3
# ['Michel Gondry', 'Jim Carrey', 'Kate Winslet', 'Tom Wilkinson', 'Gerry Robert Byrne']
#
# Amélie
# 8.3
# ['Jean-Pierre Jeunet', 'Audrey Tautou', 'Mathieu Kassovitz', 'Rufus', 'Lorella Cravotta']
#
# Snatch
# 8.3
# ['Guy Ritchie', 'Jason Statham', 'Brad Pitt', 'Benicio Del Toro', 'Dennis Farina']
#
# Requiem for a Dream
# 8.3
# ['Darren Aronofsky', 'Ellen Burstyn', 'Jared Leto', 'Jennifer Connelly', 'Marlon Wayans']
#
# L.A. Confidential
# 8.3
# ['Curtis Hanson', 'Kevin Spacey', 'Russell Crowe', 'Guy Pearce', 'Kim Basinger']
#
# Good Will Hunting
# 8.3
# ['Gus Van Sant', 'Robin Williams', 'Matt Damon', 'Ben Affleck', 'Stellan Skarsgård']
#
# Children of Heaven
# 8.3
# ['Majid Majidi', 'Mohammad Amir Naji', 'Amir Farrokh Hashemian', 'Bahare Seddiqi', 'Nafise Jafar-Mohammadi']
#
# The Bandit
# 8.3
# ['Yavuz Turgul', 'Sener Sen', 'Ugur Yücel', 'Sermin Hürmeriç', 'Yesim Salkim']
#
# Toy Story
# 8.3
# ['John Lasseter', 'Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim Varney']
#
# Reservoir Dogs
# 8.3
# ['Quentin Tarantino', 'Harvey Keitel', 'Tim Roth', 'Michael Madsen', 'Chris Penn']
#
# Full Metal Jacket
# 8.3
# ['Stanley Kubrick', 'Matthew Modine', 'R. Lee Ermey', "Vincent D'Onofrio", 'Adam Baldwin']
#
# Amadeus
# 8.3
# ['Milos Forman', 'F. Murray Abraham', 'Tom Hulce', 'Elizabeth Berridge', 'Roy Dotrice']
#
# Scarface
# 8.3
# ['Brian De Palma', 'Al Pacino', 'Michelle Pfeiffer', 'Steven Bauer', 'Mary Elizabeth Mastrantonio']
#
# Star Wars: Episode VI - Return of the Jedi
# 8.3
# ['Richard Marquand', 'Mark Hamill', 'Harrison Ford', 'Carrie Fisher', 'Billy Dee Williams']
#
# Taxi Driver
# 8.3
# ['Martin Scorsese', 'Robert De Niro', 'Jodie Foster', 'Cybill Shepherd', 'Albert Brooks']
#
# Monty Python and the Holy Grail
# 8.3
# ['Terry Gilliam', 'Terry Jones', 'Graham Chapman', 'John Cleese', 'Eric Idle', 'Terry Gilliam']
#
# The Sting
# 8.3
# ['George Roy Hill', 'Paul Newman', 'Robert Redford', 'Robert Shaw', 'Charles Durning']
#
# A Clockwork Orange
# 8.3
# ['Stanley Kubrick', 'Malcolm McDowell', 'Patrick Magee', 'Michael Bates', 'Warren Clarke']
#
# 2001: A Space Odyssey
# 8.3
# ['Stanley Kubrick', 'Keir Dullea', 'Gary Lockwood', 'William Sylvester', 'Daniel Richter']
#
# For a Few Dollars More
# 8.3
# ['Sergio Leone', 'Clint Eastwood', 'Lee Van Cleef', 'Gian Maria Volontè', 'Mario Brega']
#
# To Kill a Mockingbird
# 8.3
# ['Robert Mulligan', 'Gregory Peck', 'John Megna', 'Frank Overton', 'Rosemary Murphy']
#
# Lawrence of Arabia
# 8.3
# ['David Lean', "Peter O'Toole", 'Alec Guinness', 'Anthony Quinn', 'Jack Hawkins']
#
# Yojimbo
# 8.3
# ['Akira Kurosawa', 'Toshirô Mifune', 'Eijirô Tôno', 'Tatsuya Nakadai', 'Yôko Tsukasa']
#
# The Apartment
# 8.3
# ['Billy Wilder', 'Jack Lemmon', 'Shirley MacLaine', 'Fred MacMurray', 'Ray Walston']
#
# North by Northwest
# 8.3
# ['Alfred Hitchcock', 'Cary Grant', 'Eva Marie Saint', 'James Mason', 'Jessie Royce Landis']
#
# Vertigo
# 8.3
# ['Alfred Hitchcock', 'James Stewart', 'Kim Novak', 'Barbara Bel Geddes', 'Tom Helmore']
#
# Singin' in the Rain
# 8.3
# ['Stanley Donen', 'Gene Kelly', 'Gene Kelly', "Donald O'Connor", 'Debbie Reynolds', 'Jean Hagen']
#
# Ikiru
# 8.3
# ['Akira Kurosawa', 'Takashi Shimura', 'Nobuo Kaneko', "Shin'ichi Himori", 'Haruo Tanaka']
#
# Rashomon
# 8.3
# ['Akira Kurosawa', 'Toshirô Mifune', 'Machiko Kyô', 'Masayuki Mori', 'Takashi Shimura']
#
# All About Eve
# 8.3
# ['Joseph L. Mankiewicz', 'Bette Davis', 'Anne Baxter', 'George Sanders', 'Celeste Holm']
#
# Bicycle Thieves
# 8.3
# ['Vittorio De Sica', 'Lamberto Maggiorani', 'Enzo Staiola', 'Lianella Carell', 'Elena Altieri']
#
# Double Indemnity
# 8.3
# ['Billy Wilder', 'Fred MacMurray', 'Barbara Stanwyck', 'Edward G. Robinson', 'Byron Barr']
#
# Citizen Kane
# 8.3
# ['Orson Welles', 'Orson Welles', 'Joseph Cotten', 'Dorothy Comingore', 'Agnes Moorehead']
#
# M
# 8.3
# ['Fritz Lang', 'Peter Lorre', 'Ellen Widmann', 'Inge Landgut', 'Otto Wernicke']
#
# Metropolis
# 8.3
# ['Fritz Lang', 'Brigitte Helm', 'Alfred Abel', 'Gustav Fröhlich', 'Rudolf Klein-Rogge']
#
# The Kid
# 8.3
# ['Charles Chaplin', 'Charles Chaplin', 'Edna Purviance', 'Jackie Coogan', 'Carl Miller']
#
# Green Book
# 8.2
# ['Peter Farrelly', 'Viggo Mortensen', 'Mahershala Ali', 'Linda Cardellini', 'Sebastian Maniscalco']
#
# Pink
# 8.2
# ['Aniruddha Roy Chowdhury', 'Taapsee Pannu', 'Amitabh Bachchan', 'Kirti Kulhari', 'Andrea Tariang']
#
# A Silent Voice
# 8.2
# ['Naoko Yamada', 'Miyu Irino', 'Saori Hayami', 'Aoi Yûki', 'Kenshô Ono']
#
# Three Billboards Outside Ebbing, Missouri
# 8.2
# ['Martin McDonagh', 'Frances McDormand', 'Woody Harrelson', 'Sam Rockwell', 'Caleb Landry Jones']
#
# Talvar
# 8.2
# ['Meghna Gulzar', 'Irrfan Khan', 'Konkona Sen Sharma', 'Neeraj Kabi', 'Sohum Shah']
#
# Queen
# 8.2
# ['Vikas Bahl', 'Kangana Ranaut', 'Rajkummar Rao', 'Lisa Haydon', 'Jeffrey Ho']
#
# Room
# 8.2
# ['Lenny Abrahamson', 'Brie Larson', 'Jacob Tremblay', 'Sean Bridgers', 'Wendy Crewson']
#
# Tangerines
# 8.2
# ['Zaza Urushadze', 'Lembit Ulfsak', 'Elmo Nüganen', 'Giorgi Nakashidze', 'Misha Meskhi']
#
# Winter Sleep
# 8.2
# ['Nuri Bilge Ceylan', 'Haluk Bilginer', 'Melisa Sözen', 'Demet Akbag', 'Ayberk Pekcan']
#
# Bhaag Milkha Bhaag
# 8.2
# ['Rakeysh Omprakash Mehra', 'Farhan Akhtar', 'Sonam Kapoor', 'Pavan Malhotra', 'Art Malik']
#
# PK
# 8.2
# ['Rajkumar Hirani', 'Aamir Khan', 'Anushka Sharma', 'Sanjay Dutt', 'Boman Irani']
#
# OMG: Oh My God!
# 8.2
# ['Umesh Shukla', 'Paresh Rawal', 'Akshay Kumar', 'Mithun Chakraborty', 'Om Puri']
#
# Inside Out
# 8.2
# ['Pete Docter', 'Ronnie Del Carmen', 'Amy Poehler', 'Bill Hader', 'Lewis Black', 'Mindy Kaling']
#
# Gangs of Wasseypur
# 8.2
# ['Anurag Kashyap', 'Manoj Bajpayee', 'Richa Chadha', 'Nawazuddin Siddiqui', 'Tigmanshu Dhulia']
#
# Udaan
# 8.2
# ['Vikramaditya Motwane', 'Rajat Barmecha', 'Sanjay Gandhi', 'Ronit Roy', 'Manjot Singh']
#
# Paan Singh Tomar
# 8.2
# ['Tigmanshu Dhulia', 'Irrfan Khan', 'Hemendra Dandotiya', 'Navneet Gairola', 'Mahie Gill']
#
# The Secret in Their Eyes
# 8.2
# ['Juan José Campanella', 'Ricardo Darín', 'Soledad Villamil', 'Pablo Rago', 'Carla Quevedo']
#
# Warrior
# 8.2
# ["Gavin O'Connor", 'Tom Hardy', 'Nick Nolte', 'Joel Edgerton', 'Jennifer Morrison']
#
# A Wednesday
# 8.2
# ['Neeraj Pandey', 'Anupam Kher', 'Naseeruddin Shah', 'Jimmy Sheirgill', 'Deepal Shaw']
#
# Up
# 8.2
# ['Pete Docter', 'Bob Peterson', 'Edward Asner', 'Jordan Nagai', 'John Ratzenberger', 'Christopher Plummer']
#
# The Wolf of Wall Street
# 8.2
# ['Martin Scorsese', 'Leonardo DiCaprio', 'Jonah Hill', 'Margot Robbie', 'Matthew McConaughey']
#
# Chak de! India
# 8.2
# ['Shimit Amin', 'Shah Rukh Khan', 'Vidya Malvade', 'Sagarika Ghatge', 'Shilpa Shukla']
#
# There Will Be Blood
# 8.2
# ['Paul Thomas Anderson', 'Daniel Day-Lewis', 'Paul Dano', 'Ciarán Hinds', 'Martin Stringer']
#
# Pan's Labyrinth
# 8.2
# ['Guillermo del Toro', 'Ivana Baquero', 'Ariadna Gil', 'Sergi López', 'Maribel Verdú']
#
# V for Vendetta
# 8.2
# ['James McTeigue', 'Hugo Weaving', 'Natalie Portman', 'Rupert Graves', 'Stephen Rea']
#
# Rang De Basanti
# 8.2
# ['Rakeysh Omprakash Mehra', 'Aamir Khan', 'Soha Ali Khan', 'Siddharth', 'Sharman Joshi']
#
# Black
# 8.2
# ['Sanjay Leela Bhansali', 'Amitabh Bachchan', 'Rani Mukerji', 'Shernaz Patel', 'Ayesha Kapoor']
#
# Munna Bhai M.B.B.S.
# 8.2
# ['Rajkumar Hirani', 'Sanjay Dutt', 'Arshad Warsi', 'Gracy Singh', 'Sunil Dutt']
#
# Batman Begins
# 8.2
# ['Christopher Nolan', 'Christian Bale', 'Michael Caine', 'Ken Watanabe', 'Liam Neeson']
#
# Downfall
# 8.2
# ['Oliver Hirschbiegel', 'Bruno Ganz', 'Alexandra Maria Lara', 'Ulrich Matthes', 'Juliane Köhler']
#
# Howl's Moving Castle
# 8.2
# ['Hayao Miyazaki', 'Chieko Baishô', 'Takuya Kimura', 'Tatsuya Gashûin', 'Akihiro Miwa']
#
# A Beautiful Mind
# 8.2
# ['Ron Howard', 'Russell Crowe', 'Ed Harris', 'Jennifer Connelly', 'Christopher Plummer']
#
# Hera Pheri
# 8.2
# ['Priyadarshan', 'Akshay Kumar', 'Paresh Rawal', 'Sunil Shetty', 'Tabu']
#
# Neon Genesis Evangelion: The End of Evangelion
# 8.2
# ['Hideaki Anno', 'Kazuya Tsurumaki', 'Megumi Ogata', 'Megumi Hayashibara', 'Yûko Miyamura', 'Kotono Mitsuishi']
#
# Lock, Stock and Two Smoking Barrels
# 8.2
# ['Guy Ritchie', 'Jason Flemyng', 'Dexter Fletcher', 'Nick Moran', 'Jason Statham']
#
# Trainspotting
# 8.2
# ['Danny Boyle', 'Ewan McGregor', 'Ewen Bremner', 'Jonny Lee Miller', 'Kevin McKidd']
#
# Heat
# 8.2
# ['Michael Mann', 'Al Pacino', 'Robert De Niro', 'Val Kilmer', 'Jon Voight']
#
# Dilwale Dulhania Le Jayenge
# 8.2
# ['Aditya Chopra', 'Shah Rukh Khan', 'Kajol', 'Amrish Puri', 'Farida Jalal']
#
# Casino
# 8.2
# ['Martin Scorsese', 'Robert De Niro', 'Sharon Stone', 'Joe Pesci', 'James Woods']
#
# Andaz Apna Apna
# 8.2
# ['Rajkumar Santoshi', 'Aamir Khan', 'Salman Khan', 'Raveena Tandon', 'Karisma Kapoor']
#
# Unforgiven
# 8.2
# ['Clint Eastwood', 'Clint Eastwood', 'Gene Hackman', 'Morgan Freeman', 'Richard Harris']
#
# Raise the Red Lantern
# 8.2
# ['Yimou Zhang', 'Li Gong', 'Jingwu Ma', 'Saifei He', 'Cuifen Cao']
#
# Indiana Jones and the Last Crusade
# 8.2
# ['Steven Spielberg', 'Harrison Ford', 'Sean Connery', 'Alison Doody', 'Denholm Elliott']
#
# My Neighbor Totoro
# 8.2
# ['Hayao Miyazaki', 'Hitoshi Takagi', 'Noriko Hidaka', 'Chika Sakamoto', 'Shigesato Itoi']
#
# Die Hard
# 8.2
# ['John McTiernan', 'Bruce Willis', 'Alan Rickman', 'Bonnie Bedelia', 'Reginald VelJohnson']
#
# Come and See
# 8.2
# ['Elem Klimov', 'Aleksey Kravchenko', 'Olga Mironova', 'Liubomiras Laucevicius', 'Vladas Bagdonas']
#
# Ran
# 8.2
# ['Akira Kurosawa', 'Tatsuya Nakadai', 'Akira Terao', 'Jinpachi Nezu', 'Daisuke Ryû']
#
# Blade Runner
# 8.2
# ['Ridley Scott', 'Harrison Ford', 'Rutger Hauer', 'Sean Young', 'Edward James Olmos']
#
# Raging Bull
# 8.2
# ['Martin Scorsese', 'Robert De Niro', 'Cathy Moriarty', 'Joe Pesci', 'Frank Vincent']
#
# The Elephant Man
# 8.2
# ['David Lynch', 'Anthony Hopkins', 'John Hurt', 'Anne Bancroft', 'John Gielgud']
#
# The Message
# 8.2
# ['Moustapha Akkad', 'Anthony Quinn', 'Irene Papas', 'Michael Ansara', 'Johnny Sekka']
#
# Sholay
# 8.2
# ['Ramesh Sippy', 'Sanjeev Kumar', 'Dharmendra', 'Amitabh Bachchan', 'Amjad Khan']
#
# Chinatown
# 8.2
# ['Roman Polanski', 'Jack Nicholson', 'Faye Dunaway', 'John Huston', 'Perry Lopez']
#
# Andrei Rublev
# 8.2
# ['Andrei Tarkovsky', 'Anatoliy Solonitsyn', 'Ivan Lapikov', 'Nikolay Grinko', 'Nikolay Sergeev']
#
# The Great Escape
# 8.2
# ['John Sturges', 'Steve McQueen', 'James Garner', 'Richard Attenborough', 'Charles Bronson']
#
# Judgment at Nuremberg
# 8.2
# ['Stanley Kramer', 'Spencer Tracy', 'Burt Lancaster', 'Richard Widmark', 'Marlene Dietrich']
#
# Some Like It Hot
# 8.2
# ['Billy Wilder', 'Marilyn Monroe', 'Tony Curtis', 'Jack Lemmon', 'George Raft']
#
# Wild Strawberries
# 8.2
# ['Ingmar Bergman', 'Victor Sjöström', 'Bibi Andersson', 'Ingrid Thulin', 'Gunnar Björnstrand']
#
# The Seventh Seal
# 8.2
# ['Ingmar Bergman', 'Max von Sydow', 'Gunnar Björnstrand', 'Bengt Ekerot', 'Nils Poppe']
#
# The Bridge on the River Kwai
# 8.2
# ['David Lean', 'William Holden', 'Alec Guinness', 'Jack Hawkins', 'Sessue Hayakawa']
#
# On the Waterfront
# 8.2
# ['Elia Kazan', 'Marlon Brando', 'Karl Malden', 'Lee J. Cobb', 'Rod Steiger']
#
# Dial M for Murder
# 8.2
# ['Alfred Hitchcock', 'Ray Milland', 'Grace Kelly', 'Robert Cummings', 'John Williams']
#
# Tokyo Story
# 8.2
# ['Yasujirô Ozu', 'Chishû Ryû', 'Chieko Higashiyama', 'Sô Yamamura', 'Setsuko Hara']
#
# The Third Man
# 8.2
# ['Carol Reed', 'Orson Welles', 'Joseph Cotten', 'Alida Valli', 'Trevor Howard']
#
# The Treasure of the Sierra Madre
# 8.2
# ['John Huston', 'Humphrey Bogart', 'Walter Huston', 'Tim Holt', 'Bruce Bennett']
#
# Mr. Smith Goes to Washington
# 8.2
# ['Frank Capra', 'James Stewart', 'Jean Arthur', 'Claude Rains', 'Edward Arnold']
#
# Gone with the Wind
# 8.2
# ['Victor Fleming', 'George Cukor', 'Sam Wood', 'Clark Gable', 'Vivien Leigh', 'Thomas Mitchell', "Barbara O'Neil"]
#
# Sunrise
# 8.2
# ['F.W. Murnau', "George O'Brien", 'Janet Gaynor', 'Margaret Livingston', 'Bodil Rosing']
#
# The General
# 8.2
# ['Clyde Bruckman', 'Buster Keaton', 'Buster Keaton', 'Marion Mack', 'Glen Cavender', 'Jim Farley']
#
# The Gold Rush
# 8.2
# ['Charles Chaplin', 'Charles Chaplin', 'Mack Swain', 'Tom Murray', 'Henry Bergman']
#
# Sherlock Jr.
# 8.2
# ['Buster Keaton', 'Buster Keaton', 'Kathryn McGuire', 'Joe Keaton', 'Erwin Connelly']
#
# The Invisible Guest
# 8.1
# ['Oriol Paulo', 'Mario Casas', 'Ana Wagener', 'Jose Coronado', 'Bárbara Lennie']
#
# Airlift
# 8.1
# ['Raja Menon', 'Akshay Kumar', 'Nimrat Kaur', 'Kumud Mishra', 'Prakash Belawadi']
